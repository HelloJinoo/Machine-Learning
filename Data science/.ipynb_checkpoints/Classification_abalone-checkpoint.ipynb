# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os.path import join

from sklearn.model_selection import train_test_split

from sklearn import neighbors , datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.tree import export_graphviz

from sklearn.metrics import r2_score

# %% [markdown]
# # 1. 데이터 보기

# %%
datapath = join('data','abalone.txt')
labelpath = join('data','abalone_attributes.txt')

#txt파일 읽기
columns = list()
with open(labelpath, 'r') as f:
    columns = f.read().split('\n')
    
# cloumns = attribute    
abalone = pd.read_csv(datapath, names = columns)

abalone_M = abalone[abalone['Sex'] == 'M']
abalone_F = abalone[abalone['Sex'] == 'F']
abalone_I = abalone[abalone['Sex'] == 'I']
Y = abalone['Sex']
X = abalone

del X['Sex']
'''
le = LabelEncoder()
le.fit(Y)
Y = le.transform(Y)
'''
# Out:
# '\nle = LabelEncoder()\nle.fit(Y)\nY = le.transform(Y)\n'

# %%
X.hist(bins = 20, figsize=(10, 15))
plt.show()

# %%
fig, axs = plt.subplots(4,2)

#Diameter
axs[0, 0].boxplot([abalone_M['Diameter'], abalone_F['Diameter'], abalone_I['Diameter']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[0, 0].set_title('Diameter Boxplot')

#Height
axs[0, 1].boxplot([abalone_M['Height'], abalone_F['Height'], abalone_I['Height']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[0, 1].set_title('Height Boxplot')

#Length
axs[1, 0].boxplot([abalone_M['Length'], abalone_F['Length'], abalone_I['Length']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[1, 0].set_title('Length Boxplot')

#Rings
axs[1, 1].boxplot([abalone_M['Rings'], abalone_F['Rings'], abalone_I['Rings']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[1, 1].set_title('Rings Boxplot')

#Shell weight
axs[2, 0].boxplot([abalone_M['Shell weight'], abalone_F['Shell weight'], abalone_I['Shell weight']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[2, 0].set_title('Shell weight Boxplot')

#Shucked weight
axs[2, 1].boxplot([abalone_M['Shucked weight'], abalone_F['Shucked weight'], abalone_I['Shucked weight']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[2, 1].set_title('Shucked weight Boxplot')

#Viscera weight
axs[3, 0].boxplot([abalone_M['Viscera weight'], abalone_F['Viscera weight'], abalone_I['Viscera weight']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[3, 0].set_title('Viscera weight Boxplot')

#Whole weight
axs[3, 1].boxplot([abalone_M['Whole weight'], abalone_F['Whole weight'], abalone_I['Whole weight']],
           labels = ['M', 'F', 'I'],
           meanline = True,
           showmeans = True)
axs[3, 1].set_title('Whole weight Boxplot')

fig.subplots_adjust(left = 0.01, right = 2, bottom = 0.05, top = 2, hspace = 0.3, wspace = 0.3)

plt.show()

# %% [markdown]
# # 2. Train, Testset 분류

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 1)

# %% [markdown]
# # 3. 모델에 적용

# %% [markdown]
# ## 3.1 K-NN

# %% [markdown]
# ### 3.1.1 Model

# %%
# k 값을 의미하는 변수
k = 11
knn = neighbors.KNeighborsClassifier(n_neighbors = k )
knn.fit(X = X_train, y = Y_train)
print(" 학습 세트 정확도  : {:.3f}%".format(knn.score(X_train, Y_train) * 100))
print(" 테스트 세트 정확도: {:.3f}%".format(knn.score(X_test, Y_test) * 100))
knn_Y_pred = knn.predict(X_test)
# Out:
#  학습 세트 정확도  : 61.957%
#  테스트 세트 정확도: 51.914%

# %% [markdown]
# ### 3.1.2 시각화

# %%
knn_Y_pred = knn.predict(X = X_test)

plt.scatter(x=Y_test, y=knn_Y_pred)
plt.xlabel('Y_test')
plt.ylabel('knn_Y_pred')
# Out:
# Text(0, 0.5, 'knn_Y_pred')

# %% [markdown]
# ## 3.2 Decision Tree

# %% [markdown]
# ### 3.2.1 Model

# %%
estimator = DecisionTreeClassifier(criterion = 'entropy',
                                   max_depth = 20,
                                   max_leaf_nodes = 10,
                                  )
estimator.fit(X_train, Y_train)      
print("uniform  학습 세트 정확도  : {:.3f}%".format(estimator.score(X_train, Y_train) * 100))
print("uniform  테스트 세트 정확도: {:.3f}%".format(estimator.score(X_test, Y_test) * 100))
print("특성 중요도:\n{}".format(estimator.feature_importances_))
# Out:
# uniform  학습 세트 정확도  : 57.954%
# uniform  테스트 세트 정확도: 53.349%
# 특성 중요도:
# [0.01526352 0.         0.0658503  0.68224521 0.0163175  0.02424886
#  0.         0.19607461]

# %% [markdown]
# ### 3.2.2 시각화

# %%
n_nodes = estimator.tree_.node_count
children_left = estimator.tree_.children_left
children_right = estimator.tree_.children_right
feature = estimator.tree_.feature
threshold = estimator.tree_.threshold

node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
leaves_count = 0
#첫번째 분기의 ID는 -1이기 때문에 -1을 가진 stack 생성
stack = [(0, -1)]

#모든 분기를 순회하며 해당 분기의 깊이, 잎파리 여부를 파악
#전체 잎파리 노드의 수 조사
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1

    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True
        leaves_count += 1
        
print(np.max(node_depth))
print(leaves_count)
print(n_nodes)
# Out:
# 5
# 10
# 19

# %%
#모든 분기의 정보를 출력
#tab을 활용하여 깊이를 확인할 수 있으며 각 분기가 어떤 변수의 어떤 값을 기준으로 이루어졌는지 확인할 수 있다.
for i in range(n_nodes):
    if is_leaves[i]:
        print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
    else:
        print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
              "node %s."
              % (node_depth[i] * "\t",
                 i,
                 children_left[i],
                 feature[i],
                 threshold[i],
                 children_right[i],
                 ))
# Out:
# node=0 test node: go to node 1 if X[:, 3] <= 0.8557500243186951 else to node 2.
# 	node=1 test node: go to node 3 if X[:, 7] <= 8.5 else to node 4.
# 	node=2 test node: go to node 7 if X[:, 5] <= 0.2982500046491623 else to node 8.
# 		node=3 test node: go to node 5 if X[:, 2] <= 0.11250000074505806 else to node 6.
# 		node=4 test node: go to node 11 if X[:, 7] <= 11.5 else to node 12.
# 			node=5 leaf node.
# 			node=6 test node: go to node 9 if X[:, 3] <= 0.6389999985694885 else to node 10.
# 		node=7 leaf node.
# 		node=8 test node: go to node 13 if X[:, 4] <= 0.8737500011920929 else to node 14.
# 				node=9 leaf node.
# 				node=10 leaf node.
# 			node=11 test node: go to node 15 if X[:, 0] <= 0.5174999833106995 else to node 16.
# 			node=12 leaf node.
# 			node=13 leaf node.
# 			node=14 leaf node.
# 				node=15 leaf node.
# 				node=16 test node: go to node 17 if X[:, 3] <= 0.6742500066757202 else to node 18.
# 					node=17 leaf node.
# 					node=18 leaf node.

# %%
export_graphviz(estimator, out_file='DT_tree.dot')

# %%
estimator_Y_pred = estimator.predict(X_test)

plt.scatter(x=Y_test, y=estimator_Y_pred)
plt.xlabel('Y_test')
plt.ylabel('estimator_Y_pred')
# Out:
# Text(0, 0.5, 'estimator_Y_pred')

# %% [markdown]
# ![screensh](./image/DT_Classification.png)

# %% [markdown]
# ## 3.3 Logistic Regression

# %% [markdown]
# ### 3.3.1 Model

# %%
logreg = LogisticRegression(C=1e5, solver='lbfgs', multi_class='multinomial', max_iter = 1000)
logreg.fit(X_train, Y_train)
        
print("학습 세트 정확도: {:.3f}%".format(logreg.score(X_train, Y_train) * 100))
print("테스트 세트 정확도: {:.3f}%".format(logreg.score(X_test, Y_test) * 100))
# Out:
# 학습 세트 정확도: 56.312%
# 테스트 세트 정확도: 57.018%

# %% [markdown]
# ## 3.3.2 시각화

# %%
logreg_Y_pred = logreg.predict(X_test)

plt.scatter(x=Y_test, y=logreg_Y_pred)
plt.xlabel('Y_test')
plt.ylabel('logreg_Y_pred')
# Out:
# Text(0, 0.5, 'logreg_Y_pred')
